# %% [markdown]
# # Python Error Handling
#
# - The **try block** lets you test a block of code for errors.
#
# - The **except block** lets you handle the error.
#
# - The **else block** lets you execute code when there is no error.
#
# - The **finally block** lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# ## 1. Exception Handling
# - When an error occurs, or exception as we call it, Python will normally stop and generate an error message.
#
# - These exceptions can be handled using the try statement

# %%
try:
   # do something
   pass

except ValueError:
   # handle ValueError exception
   pass

except (TypeError, ZeroDivisionError):
   # handle multiple exceptions
   # TypeError and ZeroDivisionError
   pass

except:
   # handle all other exceptions
   pass

# %%
#Error will be occured as x is not defined
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d00d32c5a1ac> in <module>
#       1 #Error will be occured as x is not defined
# ----> 2 print(x)
#
# NameError: name 'x' is not defined

# %%
#The try block will generate an exception, because x is not defined
try:
  print(x)
except:
  print("An exception occurred")
# Out:
# An exception occurred

# %% [markdown]
# ## 2. Exceptions

# %% [markdown]
# ### a. ZeroDivisionError

# %%
10 * (1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-0b280f36835c> in <module>
# ----> 1 10 * (1/0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### b. NameError

# %%
 4 + spam*3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c98bb92cdcac> in <module>
# ----> 1 4 + spam*3
#
# NameError: name 'spam' is not defined

# %% [markdown]
# ### c. TypeError

# %%
'2' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d2b23a1db757> in <module>
# ----> 1 '2' + 2
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## 3. Handling Exceptions

# %%
while True:
    try:
        x = int(input("Please enter a number: "))
        break
    except ValueError:
         print("Oops!  That was no valid number.  Try again...")
# Out:
# Please enter a number:
# Oops!  That was no valid number.  Try again...
# Please enter a number:
# Oops!  That was no valid number.  Try again...
# Please enter a number: 3

# %%
#Example - Illustartes what order the except statements are printed
class B(Exception): #custom class exceptions
    pass

class C(B):
    pass

class D(C):
    pass

for cls in [B, C, D]:
    try:
        raise cls()
    except D:
        print("D")
    except C:
        print("C")
    except B:
        print("B")
# Out:
# B
# C
# D

# %%
#Example - Illustartes what order the except statements are printed, Here we are reversed the order of class B
class B(Exception): #exception class
    pass

class C(B):
    pass

class D(C):
    pass

for cls in [B, C, D]:
    try:
        raise cls()
    except B: #always B will be executed as it is the exception class
        print("B")
    except C:
        print("C")
    except D:
        print("D")
# Out:
# B
# B
# B

# %%
#Example- Demonstrating the OSError
import sys

try:
    f = open('myfile.txt')
    s = f.readline()
    i = int(s.strip())
except OSError as err:
    print("OS error: {0}".format(err))
except ValueError:
    print("Could not convert data to an integer.")
except BaseException as err:
    print(f"Unexpected {err=}, {type(err)=}")
    raise
# Out:
# OS error: [Errno 2] No such file or directory: 'myfile.txt'

# %%
#Example to demonstrate the OS- Error
for arg in sys.argv[1:]:
    try:
        f = open(arg, 'r')
    except OSError: #os-error
        print('cannot open', arg)
    else:
        print(arg, 'has', len(f.readlines()), 'lines')
        f.close()
# Out:
# cannot open -f
# C:\Users\Parmeet.dang\AppData\Roaming\jupyter\runtime\kernel-fc1896ce-06e2-4c1a-9f02-03234c70deb2.json has 12 lines

# %%
#Example- Demostration exception with arguments
try:
    raise Exception('spam', 'eggs')
except Exception as inst:
    print("Type of instance : ",type(inst))    # the exception instance
    print("Arguments : ",inst.args)            # arguments stored in .args
    print("Printing Instances Directly : ",inst) # __str__ allows args to be printed directly,
                                                 # but may be overridden in exception subclasses
    x, y = inst.args     # unpack args
    print('x =', x)
    print('y =', y)
# Out:
# Type of instance :  <class 'Exception'>
# Arguments :  ('spam', 'eggs')
# Printing Instances Directly :  ('spam', 'eggs')
# x = spam
# y = eggs

# %%
#Exception handlers with functions demonstration
def this_fails():
     x = 1/0

try:
    this_fails()
except ZeroDivisionError as err:
    print('Handling run-time error:', err)
# Out:
# Handling run-time error: division by zero

# %% [markdown]
# ## 4. Raising Exceptions

# %%
raise NameError('HiThere')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-72c183edb298> in <module>
# ----> 1 raise NameError('HiThere')
#
# NameError: HiThere

# %%
raise ValueError  # shorthand for 'raise ValueError()'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-496f17a27c64> in <module>
# ----> 1 raise ValueError  # shorthand for 'raise ValueError()'
#
# ValueError:

# %%
#Example - Demonstarting NameError
try:
    raise NameError('HiThere')
except NameError:
    print('An exception flew by!')
    raise
# Out:
# An exception flew by!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-bf6ef4926f8c> in <module>
#       1 try:
# ----> 2     raise NameError('HiThere')
#       3 except NameError:
#       4     print('An exception flew by!')
#       5     raise
#
# NameError: HiThere

# %% [markdown]
# ## 5. Exception Chaining

# %%
# exc must be exception instance or None.
raise RuntimeError from exc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-77bcbe771108> in <module>
#       1 # exc must be exception instance or None.
# ----> 2 raise RuntimeError from exc
#
# NameError: name 'exc' is not defined

# %%
#Example Demonstrating transforming exceptions
def func():
    raise ConnectionError
    
try:
    func()
except ConnectionError as exc:
    raise RuntimeError('Failed to open database') from exc
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-18-41e851d7b84e> in <module>
#       5 try:
# ----> 6     func()
#       7 except ConnectionError as exc:
#
# <ipython-input-18-41e851d7b84e> in func()
#       2 def func():
# ----> 3     raise ConnectionError
#       4
#
# ConnectionError:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-41e851d7b84e> in <module>
#       6     func()
#       7 except ConnectionError as exc:
# ----> 8     raise RuntimeError('Failed to open database') from exc
#
# RuntimeError: Failed to open database

# %%
#Example Demonstrating run time error
try:
    open('database.sqlite')
except OSError:
    raise RuntimeError from None
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-b406eef36fda> in <module>
#       3     open('database.sqlite')
#       4 except OSError:
# ----> 5     raise RuntimeError from None
#
# RuntimeError:

# %%
raise KeyboardInterrupt
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-c761920b81b0> in <module>
# ----> 1 raise KeyboardInterrupt
#
# KeyboardInterrupt:

# %%
 raise MemoryError("This is an argument")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-21-51782e52f201> in <module>
# ----> 1 raise MemoryError("This is an argument")
#
# MemoryError: This is an argument

# %%
#Example - Demonstrating value Error
try:
    a = int(input("Enter a positive integer: "))
    if a <= 0:
        raise ValueError("That is not a positive number!")
except ValueError as ve:
    print(ve)
# Out:
# Enter a positive integer: -1
# That is not a positive number!

# %% [markdown]
# ## 6. User Defined Exceptions

# %%
# import module sys to get the type of exception
import sys

randomList = ['a', 0, 2]

for entry in randomList:
    try:
        print("The entry is", entry)
        r = 1/int(entry)
        break
    except:
        print("Oops!", sys.exc_info()[0], "occurred.")
        print("Next entry.")
        print()
print("The reciprocal of", entry, "is", r)
# Out:
# The entry is a
# Oops! <class 'ValueError'> occurred.
# Next entry.
#
# The entry is 0
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
#
# The entry is 2
# The reciprocal of 2 is 0.5

# %%
# program to print the reciprocal of even numbers

try:
    num = int(input("Enter a number: "))
    assert num % 2 == 0
except:
    print("Not an even number!")
else:
    reciprocal = 1/num
    print(reciprocal)
# Out:
# Enter a number: parmeet
# Not an even number!

# %%
#finally clause
try:
   f = open("test.txt",encoding = 'utf-8')
   # perform file operations
finally:
   f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-0b3e25bcf267> in <module>
#       1 #finally clause
#       2 try:
# ----> 3    f = open("test.txt",encoding = 'utf-8')
#       4    # perform file operations
#       5 finally:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
# define Python user-defined exceptions
class Error(Exception):
    """Base class for other exceptions"""
    pass


class ValueTooSmallError(Error):
    """Raised when the input value is too small"""
    pass


class ValueTooLargeError(Error):
    """Raised when the input value is too large"""
    pass


# you need to guess this number
number = 10

# user guesses a number until he/she gets it right
while True:
    try:
        i_num = int(input("Enter a number: "))
        if i_num < number:
            raise ValueTooSmallError
        elif i_num > number:
            raise ValueTooLargeError
        break
    except ValueTooSmallError:
        print("This value is too small, try again!")
        print()
    except ValueTooLargeError:
        print("This value is too large, try again!")
        print()

print("Congratulations! You guessed it correctly.")
# Out:
# Enter a number: 1
# This value is too small, try again!
#
# Enter a number: parmeet
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-a3063f2b956f> in <module>
#      21 while True:
#      22     try:
# ---> 23         i_num = int(input("Enter a number: "))
#      24         if i_num < number:
#      25             raise ValueTooSmallError
#
# ValueError: invalid literal for int() with base 10: 'parmeet'

# %% [markdown]
# ## 7. Python Custom Exceptions

# %%
class CustomError(Exception):
    pass

raise CustomerError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-55100fe85460> in <module>
#       2     pass
#       3
# ----> 4 raise CustomerError
#
# NameError: name 'CustomerError' is not defined

# %%
raise CustomError("An error occurred")
# Out:
# ---------------------------------------------------------------------------
# CustomError                               Traceback (most recent call last)
# <ipython-input-29-d75c9779269a> in <module>
# ----> 1 raise CustomError("An error occurred")
#
# CustomError: An error occurred

# %%
#Sample Program Demonstration
# define Python user-defined exceptions
class Error(Exception):
    """Base class for other exceptions"""
    pass


class ValueTooSmallError(Error):
    """Raised when the input value is too small"""
    pass


class ValueTooLargeError(Error):
    """Raised when the input value is too large"""
    pass


# you need to guess this number
number = 10

# user guesses a number until he/she gets it right
while True:
    try:
        i_num = int(input("Enter a number: "))
        if i_num < number:
            raise ValueTooSmallError
        elif i_num > number:
            raise ValueTooLargeError
        break
    except ValueTooSmallError:
        print("This value is too small, try again!")
        print()
    except ValueTooLargeError:
        print("This value is too large, try again!")
        print()

print("Congratulations! You guessed it correctly.")
# Out:
# Enter a number: 4
# This value is too small, try again!
#
# Enter a number: -1
# This value is too small, try again!
#
# Enter a number: 100000000000000000000000000
# This value is too large, try again!
#
# Enter a number: 10
# Congratulations! You guessed it correctly.

# %%
#Example- Demonstrating the custom error
class SalaryNotInRangeError(Exception):
    """Exception raised for errors in the input salary.

    Attributes:
        salary -- input salary which caused the error
        message -- explanation of the error
    """

    def __init__(self, salary, message="Salary is not in (5000, 15000) range"):
        self.salary = salary
        self.message = message
        super().__init__(self.message)


salary = int(input("Enter salary amount: "))
if not 5000 < salary < 15000:
    raise SalaryNotInRangeError(salary)
# Out:
# Enter salary amount: -100
# ---------------------------------------------------------------------------
# SalaryNotInRangeError                     Traceback (most recent call last)
# <ipython-input-31-6ab0f28c63a7> in <module>
#      15 salary = int(input("Enter salary amount: "))
#      16 if not 5000 < salary < 15000:
# ---> 17     raise SalaryNotInRangeError(salary)
#
# SalaryNotInRangeError: Salary is not in (5000, 15000) range

# %%
#Example - customize the __str__ method itself by overriding it
class SalaryNotInRangeError(Exception):
    """Exception raised for errors in the input salary.

    Attributes:
        salary -- input salary which caused the error
        message -- explanation of the error
    """

    def __init__(self, salary, message="Salary is not in (5000, 15000) range"):
        self.salary = salary
        self.message = message
        super().__init__(self.message)

    def __str__(self):
        return f'{self.salary} -> {self.message}'


salary = int(input("Enter salary amount: "))
if not 5000 < salary < 15000:
    raise SalaryNotInRangeError(salary)
# Out:
# Enter salary amount: 50001
# ---------------------------------------------------------------------------
# SalaryNotInRangeError                     Traceback (most recent call last)
# <ipython-input-33-2e3826a37cc8> in <module>
#      19 salary = int(input("Enter salary amount: "))
#      20 if not 5000 < salary < 15000:
# ---> 21     raise SalaryNotInRangeError(salary)
#
# SalaryNotInRangeError: 50001 -> Salary is not in (5000, 15000) range
