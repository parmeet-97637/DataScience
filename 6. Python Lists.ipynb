# %% [markdown]
# # List
# - Lists are used to store multiple items in a single variable.
# - Lists are created using square brackets
#
# # Properties: -
# ## List Items
# - List items are ordered, changeable, and allow duplicate values.
# - List items are indexed, the first item has index [0], the second item has index [1] etc.
#
# ## Ordered
# - When we say that lists are ordered, it means that the items have a defined order, and that order will not change.
# - If you add new items to a list, the new items will be placed at the end of the list.
#
# ## Mutable(changeable)
# - The list is mutable, meaning that we can change, add, and remove items in a list after it has been created.
#
# ## Allow Duplicates
# - Since lists are indexed, lists can have items with the same value

# %% [markdown]
# # 1. Creating the empty list

# %%
#Method-1
list1 = []
print(list1)
print(type(list1))
# Out:
# []
# <class 'list'>

# %%
#Method-2
list1 = list()
print(list1)
print(type(list1))
# Out:
# []
# <class 'list'>

# %% [markdown]
# # 2. Creating the list with elements

# %%
#Creating list of words
list1 = ["apple", "banana", "cherry"]
print(list1)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#creating list of numbers
list2 = [1,2,3,4,5]
print(list2)
# Out:
# [1, 2, 3, 4, 5]

# %%
#creating list of boolean elements
list3 = [True, False, True,True, False,False]
print(list3)
# Out:
# [True, False, True, True, False, False]

# %%
#creating list with combination of strings, numbers and boolean
list3 = ["apple", 1,"banana",2.5,False, "cherry",3,True]
print(list3)
# Out:
# ['apple', 1, 'banana', 2.5, False, 'cherry', 3, True]

# %% [markdown]
# # 3. Creating list with duplicate elements

# %%
list1 = ["apple", "banana", "cherry", "apple", "cherry"]
print(list1)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %% [markdown]
# # 4. Find the length of the string

# %%
#len function determine how many items a list has
len(list1)
# Out:
# 5

# %% [markdown]
# # 5. Accessing elements in a list

# %%
list1 =["apple", 1,"banana",2.5,False, "cherry",3,True]

# %% [markdown]
# ## a. Positive Indexing

# %%
list1[1] #Extract the element place at the second index
# Out:
# 1

# %% [markdown]
# ## b. Negative Indexing

# %%
#Extracting last element in a list
'''Negative indexing means start from the end -1 refers to the last item, -2 refers to the second last item etc'''
list1[-1]
# Out:
# True

# %% [markdown]
# ## c.Range of Indexes
# - You can specify a range of indexes by specifying where to start and where to end the range.
#
# - When specifying a range, the return value will be a new list with the specified items.

# %%
#Extracting all the elements starting from index 1 till 5th index
list1[1:6] #[start:stop:skip]
# Out:
# [1, 'banana', 2.5, False, 'cherry']

# %%
list1[:4] # returns the items from the beginning till given stop position
# Out:
# ['apple', 1, 'banana', 2.5]

# %%
list1[5:] #returns all the item from starting 5th index till last
# Out:
# ['cherry', 3, True]

# %%
#Extracting all the alternative elements in the list
list1[::2]
# Out:
# ['apple', 'banana', False, 3]

# %% [markdown]
# ## d. Range of Negative Indexes
# - Specify negative indexes if you want to start the search from the end of the list

# %%
list1[-4:-2] #strating from -4 index and going till -2
# Out:
# [False, 'cherry']

# %%
#Extracting 1st and 4th element
import operator #importing external library
sub_list = operator.itemgetter(1, 4,5) #creating itemgetter object
sub_list(list1)
# Out:
# (1, False, 'cherry')

# %% [markdown]
# # 6. Check if Item Exists
# - o determine if a specified item is present in a list use the "in" keyword

# %%
item_list = ["apple", "banana", "cherry"]
if "apple" in item_list:
    print("Yes, 'apple' is in the fruits list")
# Out:
# Yes, 'apple' is in the fruits list

# %% [markdown]
# # 7. Changing List of Items

# %% [markdown]
# ## a. Change Item Value
# - To change the value of a specific item, refer to the index number

# %%
item_list = ["apple", "banana", "cherry"]
print("Original list : ",item_list)
item_list[1] = "watermelon" #replacing banana by watermelon
print("Updated list : ",item_list)
# Out:
# Original list :  ['apple', 'banana', 'cherry']
# Updated list :  ['apple', 'watermelon', 'cherry']

# %% [markdown]
# ## b.Change a Range of Item Values
# - To change the value of items within a specific range, define a list with the new values, and refer to the range of index numbers where you want to insert the new values

# %%
#Change the values "banana" and "cherry" with the values "papaya" and grapes
item_list = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
print("Original list : ",item_list)
item_list[1:3] = ["papaya", "grapes"]
print("Updated list : ",item_list)
# Out:
# Original list :  ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'mango']
# Updated list :  ['apple', 'papaya', 'grapes', 'orange', 'kiwi', 'mango']

# %% [markdown]
# <b>If you insert more items than you replace, the new items will be inserted where you specified, and the remaining items will move accordingly

# %%
item_list = ["apple", "banana", "cherry"]
print("Original list : ",item_list)
item_list[1:2] = ["papaya", "grapes"] #Change the second value by replacing it with two new values
print("Updated list : ",item_list)
# Out:
# Original list :  ['apple', 'banana', 'cherry']
# Updated list :  ['apple', 'papaya', 'grapes', 'cherry']

# %% [markdown]
# <b>If you insert less items than you replace, the new items will be inserted where you specified, and the remaining items will move accordingly

# %%
item_list = ["apple", "banana", "cherry"]
print("Original list : ",item_list)
item_list[1:3] = ["papaya"] #Change the second and third value by replacing it with one value
print("Updated list : ",item_list)
# Out:
# Original list :  ['apple', 'banana', 'cherry']
# Updated list :  ['apple', 'papaya']

# %% [markdown]
# # 8. Add List Items

# %% [markdown]
# ## a. Append Items
# - To add an item to the end of the list, use the append() method

# %%
list1 = ["apple", "banana", "cherry"]
print("Original list : ",list1)
list1.append("orange") #element append at the last
print("Updated List : ",list1)
# Out:
# Original list :  ['apple', 'banana', 'cherry']
# Updated List :  ['apple', 'banana', 'cherry', 'orange']

# %%
print("List 1 : ",list1)
list2 = ['mango','papaya']
print("List2 : ",list2)
list1.append(list2) #whole list is appended
print("After Appending list1 and list2 - Updated List1 : ",list1)
# Out:
# List 1 :  ['apple', 'banana', 'cherry', 'orange']
# List2 :  ['mango', 'papaya']
# After Appending list1 and list2 - Updated List1 :  ['apple', 'banana', 'cherry', 'orange', ['mango', 'papaya']]

# %% [markdown]
# ## b. Extend Items
# - To append elements from another list to the current list, use the extend() method.

# %%
list1 = ["apple", "banana", "cherry"]
list2 = ['mango','papaya']
print("List1 : ",list1)
print("List2 : ",list2)
list1.extend(list2) #list1 is extended
print("Updated List1 after extending list1 and list2 : ",list1)
# Out:
# List1 :  ['apple', 'banana', 'cherry']
# List2 :  ['mango', 'papaya']
# Updated List1 after extending list1 and list2 :  ['apple', 'banana', 'cherry', 'mango', 'papaya']

# %%
print("Original List1 : ",list1)
list1.extend("orange")
print("Updated List1 after list1 is extended : ",list1)
# Out:
# Original List1 :  ['apple', 'banana', 'cherry', 'mango', 'papaya']
# Updated List1 after list1 is extended :  ['apple', 'banana', 'cherry', 'mango', 'papaya', 'o', 'r', 'a', 'n', 'g', 'e']

# %% [markdown]
# ## c. Insert Items
# - To insert a new list item, without replacing any of the existing values, we can use the insert() method

# %%
list1 = ["apple", "banana", "cherry"]
list1.insert(2, "watermelon") #inserting new element as index 2
print(list1)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %% [markdown]
# # 9.Remove List Items

# %% [markdown]
# ## a. Remove Specified Item
# - The remove() method removes the specified item

# %%
list1 = ["apple", "banana", "cherry"]
list1.remove("banana")
print(list1)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# ## b. Remove Specified Index - using pop
# - The pop() method removes the specified index.

# %%
list1 = ["apple", "banana", "cherry"]
list1.pop(1) #removing element at first index
print(list1)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# <b> pop will return the element but remove would not return the removed element

# %%
list1 = ["apple", "banana", "cherry"]
list1.remove("banana")

# %%
list1 = ["apple", "banana", "cherry"]
list1.pop(1)
# Out:
# 'banana'

# %% [markdown]
# ## c. Remove Specified Index - using del
# - The del keyword also removes the specified index

# %%
list1 = ["apple", "banana", "cherry"]
del list1[0]
print(list1)
# Out:
# ['banana', 'cherry']

# %% [markdown]
# <b> The del keyword can also delete the list completely.

# %%
del list1

# %%
list1 #list onow doesnot exisit as we have deleted whole list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-d019f001d152> in <module>
# ----> 1 list1 #list onow doesnot exisit as we have deleted whole list
#
# NameError: name 'list1' is not defined

# %% [markdown]
# ## d. Clear the List
# - The clear() method empties the list.
#
# - The list still remains, but it has no content.

# %%
list1 = ["apple", "banana", "cherry"]
print("Original List : ",list1)
list1.clear()
print("After applying clear method : ",list1)
# Out:
# Original List :  ['apple', 'banana', 'cherry']
# After applying clear method :  []

# %% [markdown]
# # 10. Sort Lists

# %% [markdown]
# ## a. Sort List Ascending order
# - List objects have a sort() method that will sort the list alphanumerically, ascending, by default

# %%
#Sorting list of strings
list1 = ["orange", "mango", "kiwi", "pineapple", "banana"]
list1.sort() #default is ascending order
print(list1)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
#Soritng numerical list
list1 = [100, 50, 65, 82, 23]
list1.sort() #default is ascending order
print(list1)
# Out:
# [23, 50, 65, 82, 100]

# %%
#Soritng alphanumericl
list1 = ['apple',100,'papaya' ,50, 'cherry',65, 'banana',82, 23]
list1.sort() # sort is not supportted on combination of lists with integer and string 
print(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-019bc58e721a> in <module>
#       1 #Soritng alphanumericl
#       2 list1 = ['apple',100,'papaya' ,50, 'cherry',65, 'banana',82, 23]
# ----> 3 list1.sort() # sort is not supportted on combination of lists with integer and string
#       4 print(list1)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# ## b. Sorting List in Descending Order

# %%
#Sorting list of strings
list1 = ["orange", "mango", "kiwi", "pineapple", "banana"]
list1.sort(reverse = True) #default is ascending order
print(list1)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
#Soritng numerical list
list1 = [100, 50, 65, 82, 23]
list1.sort(reverse = True) #default is ascending order
print(list1)
# Out:
# [100, 82, 65, 50, 23]

# %% [markdown]
# ## c. Customize Sort Function
# - You can also customize your own function by using the keyword argument key = function.
#
# - The function will return a number that will be used to sort the list (the lowest number first)

# %%
def myfunc(n):
    return abs(n - 50)

list1 = [100, 50, 65, 82, 23]
list1.sort(key = myfunc) #keys -[50,0,15,32,abs(-27)] => [50,0,15,32,27]
print(list1)
# Out:
# [50, 65, 23, 82, 100]

# %% [markdown]
# ## d. Case Insensitive Sort
# - By default the sort() method is case sensitive, resulting in all capital letters being sorted before lower case letters

# %%
#Case sensitive sorting can give an unexpected result
list1 = ["banana", "Orange", "Kiwi", "cherry"]
list1.sort()
print(list1)
# Out:
# ['Kiwi', 'Orange', 'banana', 'cherry']

# %%
#Perform a case-insensitive sort of the list
list1 = ["banana", "Orange", "Kiwi", "cherry"]
list1.sort(key = str.lower)
print(list1)
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %% [markdown]
# ## e. Reverse Order
# - What if you want to reverse the order of a list, regardless of the alphabet?
#
# - The reverse() method reverses the current sorting order of the elements.

# %%
list1 = ["banana", "Orange", "Kiwi", "cherry"]
list1.reverse() 
print(list1)
# Out:
# ['cherry', 'Kiwi', 'Orange', 'banana']

# %% [markdown]
# # 11.Copy Lists
# - You cannot copy a list simply by typing list2 = list1, because: list2 will only be a reference to list1, and changes made in list1 will automatically also be made in list2.
#
# - There are ways to make a copy, one way is to use the built-in List method copy().

# %% [markdown]
# ## a. Shallow Copy

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list1 = ["apple", "banana", "cherry"]
list2 = list1 #shallow copy
print("List1 : ",list1)
print("List2 : ",list2)
# Out:
# List1 :  ['apple', 'banana', 'cherry']
# List2 :  ['apple', 'banana', 'cherry']

# %%
#performing operation on list1
list1.append("papaya") #appending a new element in list1
print("After updating list1 : ", list1)
print("After updating list1, let us see what changed in list2 : ",list2)
print("You see that as we did shallow copy the changes we did in list1 got affected in list2 also.")
# Out:
# After updating list1 :  ['apple', 'banana', 'cherry', 'papaya']
# After updating list1, let us see what changed in list2 :  ['apple', 'banana', 'cherry', 'papaya']
# You see that as we did shallow copy the changes we did in list1 got affected in list2 also.

# %%
#checking the identity of list1 and list2
print("List1 Identity : ", id(list1))
print("List2 Identity : ",id(list2))
# Out:
# List1 Identity :  1554456384640
# List2 Identity :  1554456384640

# %% [markdown]
# <b> Both list1 and list2 shares same identity as new object was logically not created and both the lists are pointing to the same location

# %% [markdown]
# ## b. Deep Copy

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list1 = ["apple", "banana", "cherry"]
list2 = list1.copy() #Deep copy
print("List1 : ",list1)
print("List2 : ",list2)
# Out:
# List1 :  ['apple', 'banana', 'cherry']
# List2 :  ['apple', 'banana', 'cherry']

# %%
#performing operation on list1
list1.append("papaya") #appending a new element in list1
print("After updating list1 : ", list1)
print("After updating list1, let us see what changed in list2 : ",list2)
print("You see that as we did Deep copy the changes we did in list1 does not affect list2.")
# Out:
# After updating list1 :  ['apple', 'banana', 'cherry', 'papaya']
# After updating list1, let us see what changed in list2 :  ['apple', 'banana', 'cherry']
# You see that as we did Deep copy the changes we did in list1 does not affect list2.

# %%
#checking the identity of list1 and list2
print("List1 Identity : ", id(list1))
print("List2 Identity : ",id(list2))
# Out:
# List1 Identity :  1554456714880
# List2 Identity :  1554456384704

# %% [markdown]
# <b> Both list1 and list2 shares different identity as new object was created and both the lists are pointing to the different location

# %% [markdown]
# # 13. Join Lists

# %% [markdown]
# ## a. Join Two Lists
# - There are several ways to join, or concatenate, two or more lists in Python.
#
# - One of the easiest ways are by using the + operator.

# %%
#Example-1
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
#Example-2
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
    list1.append(x)

print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
#Use the extend() method to add list2 at the end of list1
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]
list1.extend(list2)
list1
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [markdown]
# # 14. Other Functions in List

# %% [markdown]
# ## a. count()
# - Returns the number of elements with the specified value

# %%
fruits = ['apple', 'banana', 'cherry', "banana"]
x = fruits.count("banana")
x
# Out:
# 2
